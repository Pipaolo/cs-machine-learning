# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Student Number, Proficiency, Grade
df = pd.DataFrame([
    [1, 60, 70],
    [2, 90, 95],
    [3, 70, 70],
    [4, 85, 75],
    [5, 80, 90],
    [6, 65, 75],
    [7, 75, 75],
    [8, 60, 60],
    [9, 75, 80],
    [10, 70, 65]
], columns=['Student Number', 'Proficiency', 'Grade'])

# %%
corr_matrix = df.corr() 
corr_matrix
# Out:
#                 Student Number  Proficiency     Grade
# Student Number        1.000000    -0.200731 -0.370126
# Proficiency          -0.200731     1.000000  0.787882
# Grade                -0.370126     0.787882  1.000000

# %%
# Correlation between Proficiency and Grade
grade_corr = corr_matrix['Grade']

# %%
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()
